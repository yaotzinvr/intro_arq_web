# %%
import psycopg2
import pandas as pd
import pymongo
from sqlalchemy import create_engine

# %%
cadena_mongo = 'mongodb://root:toor@localhost:27017'

# %%
cadena_postgresql = 'postgres://euokdekd:w_e5e-bVjrvUIMsU_Q1sTPwh3eROJQTy@ruby.db.elephantsql.com:5432/euokdekd'
cadena_mongo = 'mongodb+srv://admin:toor@cluster0-uzjjh.mongodb.net/pokemones?retryWrites=true&w=majority'

# %%
client = pymongo.MongoClient(cadena_mongo)

# %%
client.database_names()
# Out:
# /home/yao/proyectos/curso_arq_web/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-43-896185ff0974> in <module>
# ----> 1 client.database_names()
#
# ~/proyectos/curso_arq_web/venv/lib/python3.6/site-packages/pymongo/mongo_client.py in database_names(self, session)
#    1925         warnings.warn("database_names is deprecated. Use list_database_names "
#    1926                       "instead.", DeprecationWarning, stacklevel=2)
# -> 1927         return self.list_database_names(session)
#    1928
#    1929     def drop_database(self, name_or_database, session=None):
#
# ...

# %%
client.pokemones.pokemon
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'pokemones'), 'pokemon')

# %%
client.list_collection_names()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e16f390239b0> in <module>
# ----> 1 client.list_collection_names()
#
# ~/proyectos/curso_arq_web/venv/lib/python3.6/site-packages/pymongo/database.py in __call__(self, *args, **kwargs)
#    1543                         "call the '%s' method on a '%s' object it is "
#    1544                         "failing because no such method exists." % (
# -> 1545                             self.__name, self.__client.__class__.__name__))
#    1546
#    1547
#
# TypeError: 'Database' object is not callable. If you meant to call the 'list_collection_names' method on a 'MongoClient' object it is failing because no such method exists.

# %% [markdown]
# # Leyendo de PostgreSQL

# %%
engine = create_engine(cadena_postgresql)

# %%
df = pd.read_sql_query('select * from pokemon',con=engine)
df
# Out:
#         id                abilities against_bug against_dark against_dragon  \
# 0        1  [Overgrow, Chlorophyll]         1.0          1.0            1.0
# 1        2  [Overgrow, Chlorophyll]         1.0          1.0            1.0
# 2        3  [Overgrow, Chlorophyll]         1.0          1.0            1.0
# 3        4     [Blaze, Solar Power]         0.5          1.0            1.0
# 4        5     [Blaze, Solar Power]         0.5          1.0            1.0
# ...    ...                      ...         ...          ...            ...
# 1597  1598            [Beast Boost]        0.25          1.0            0.5
# 1598  1599            [Beast Boost]         1.0          1.0            0.5
# 1599  1600            [Beast Boost]         2.0          0.5            2.0
# 1600  1601            [Prism Armor]         2.0          2.0            1.0
# 1601  1602             [Soul-Heart]        0.25          0.5            0.0
#
# ...

# %% [markdown]
# # Insertando en MongoDB

# %%
df.to_dict('records')
# Out:
# [{'id': 1,
#   'abilities': '[Overgrow, Chlorophyll]',
#   'against_bug': '1.0',
#   'against_dark': '1.0',
#   'against_dragon': '1.0',
#   'against_electric': '0.5',
#   'against_fairy': '0.5',
#   'against_fight': '0.5',
#   'against_fire': '2.0',
#   'against_flying': '2.0',
#   'against_ghost': '1.0',
#   'against_grass': '0.25',
#   'against_ground': '1.0',
#   'against_ice': '2.0',
#   'against_normal': '1.0',
#   'against_poison': '1.0',
#   'against_psychic': '2.0',
#   'against_rock': '1.0',
#   'against_steel': '1.0',
#   'against_water': '0.5',
#   'attack': '49',
#   'base_egg_steps': '5120',
#   'base_happiness': '70',
#   'base_total': '318',
#   'capture_rate': '45',
#   'classfication': 'Seed Pokémon',
#   'defense': '49',
#   'experience_growth': '1059860',
#   'height_m': '0.7',
#   'hp': '45',
#   'japanese_name': 'Fushigidaneフシギダネ',
#   'name': 'Bulbasaur',
#   'percentage_male': '88.1',
#   'pokedex_number': '1',
#   'sp_attack': '65',
#   'sp_defense': '65',
# ...

# %%
for d in df.to_dict('records'):
    client.pokemones.pokemon.save(d)
# Out:
# /home/yao/proyectos/curso_arq_web/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: save is deprecated. Use insert_one or replace_one instead
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-30-48206cede694> in <module>
#       1 for d in df.to_dict('records'):
# ----> 2     client.pokemones.pokemon.save(d)
#
# ~/proyectos/curso_arq_web/venv/lib/python3.6/site-packages/pymongo/collection.py in save(self, to_save, manipulate, check_keys, **kwargs)
#    3156         if not (isinstance(to_save, RawBSONDocument) or "_id" in to_save):
#    3157             return self._insert(
# -> 3158                 to_save, True, check_keys, manipulate, write_concern)
#    3159         else:
#    3160             self._update_retryable(
#
# ...
